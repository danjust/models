# %%
import tensorflow as tf
import cifar10_input
import os
from six.moves import xrange
import pickle
import matplotlib.pyplot as plt
import sys

# %%
data_dir = '/Users/djustus/Data/cifar10/cifar-10-batches-py'

# %%
with tf.device('/cpu:0'):
      images, labels = cifar10_input.distorted_inputs(data_dir,50000)

# %%
filenames = [os.path.join(data_dir, 'data_batch_%d' % i) for i in range(1, 6)]
for f in filenames:
    d = unpickle(f)

# %%
sys.version_info.major
# Out:
# 3

# %%
with tf.Session() as sess:
    im = sess.run(images)

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# %%
filenames = [os.path.join(data_dir, 'data_batch_%d.bin' % i) for i in range(1, 6)]

# %%
d = unpickle('/Users/djustus/Data/cifar10/cifar-10-batches-py/data_batch_1')

# %%
img = d[b'data'].reshape([10000,3,32,32])
img = np.transpose(img, (0, 2, 3, 1))
plt.imshow(img[2])

# %%
d[b'labels']
# Out:
# [6,
#  9,
#  9,
#  4,
#  1,
#  1,
#  2,
#  7,
#  8,
#  3,
#  4,
#  7,
#  7,
#  2,
#  9,
#  9,
#  9,
#  3,
#  2,
#  6,
#  4,
#  3,
#  6,
#  6,
#  2,
#  6,
#  3,
#  5,
#  4,
#  0,
#  0,
#  9,
#  1,
#  3,
#  4,
#  0,
#  3,
#  7,
#  3,
#  3,
#  5,
#  2,
#  2,
#  7,
#  1,
#  1,
#  1,
#  2,
#  2,
#  0,
#  9,
#  5,
#  7,
#  9,
#  2,
#  2,
#  5,
#  2,
#  4,
#  3,
#  1,
#  1,
#  8,
#  2,
#  1,
#  1,
#  4,
#  9,
#  7,
#  8,
#  5,
#  9,
#  6,
#  7,
#  3,
#  1,
#  9,
#  0,
#  3,
#  1,
#  3,
#  5,
#  4,
#  5,
#  7,
#  7,
#  4,
#  7,
#  9,
#  4,
#  2,
#  3,
#  8,
#  0,
#  1,
#  6,
#  1,
#  1,
#  4,
#  1,
#  8,
#  3,
#  9,
#  6,
#  6,
#  1,
#  8,
#  5,
#  2,
#  9,
#  9,
#  8,
#  1,
#  7,
#  7,
#  0,
#  0,
#  6,
#  9,
#  1,
#  2,
#  2,
#  9,
#  2,
#  6,
#  6,
#  1,
#  9,
#  5,
#  0,
#  4,
#  7,
#  6,
#  7,
#  1,
#  8,
#  1,
#  1,
#  2,
#  8,
#  1,
#  3,
#  3,
#  6,
#  2,
#  4,
#  9,
#  9,
#  5,
#  4,
#  3,
#  6,
#  7,
#  4,
#  6,
#  8,
#  5,
#  5,
#  4,
#  3,
#  1,
#  8,
#  4,
#  7,
#  6,
#  0,
# ...

# %%
lb=np.zeros([50000])

# %%
lb[0:10000]=(d[b'labels'])

# %%
np.int8(lb)
# Out:
# array([6, 9, 9, ..., 0, 0, 0], dtype=int8)

# %%
lbl=np.zeros([50000,10])

# %%
lbl[np.arange(50000),np.int8(lb)]=1

# %%
np.size(lbl,0)
# Out:
# 50000
